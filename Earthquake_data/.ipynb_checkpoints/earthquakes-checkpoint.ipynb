# %%
import json
import requests

# %%
quakes = requests.get("http://earthquake.usgs.gov/fdsnws/event/1/query.geojson",
                      params={
                          'starttime': "2000-01-01",
                          "maxlatitude": "58.723",
                          "minlatitude": "50.008",
                          "maxlongitude": "1.67",
                          "minlongitude": "-9.756",
                          "minmagnitude": "1",
                          "endtime": "2018-10-11",
                          "orderby": "time-asc"})
quakes.text[0:100]
# Out:
# u'{"type":"FeatureCollection","metadata":{"generated":1571913506000,"url":"https://earthquake.usgs.gov'

# %%
data = quakes.json()

# %%
with open('us_quakes.json','w') as f:
    json.dump(data,f)

# %%
with open('us_quakes.json') as f:
    raw_data = json.load(f)
mag_list=[]
feat = raw_data['features']
largest_mag = feat[0]
for feats in feat:
    if feats['properties']['mag'] > largest_mag['properties']['mag']:
        largest_mag = feats
largest_mag['properties']['mag']
# Out:
# 4.8

# %%
lat = largest_mag['geometry']['coordinates'][1]
long = largest_mag['geometry']['coordinates'][0]
print("Latitude: {} Longitude: {}".format(lat, long))
# Out:
# Latitude: 52.52 Longitude: -2.15

# %%
print(feat)
# Out:
# [{u'geometry': {u'type': u'Point', u'coordinates': [-2.81, 54.77, 14]}, u'type': u'Feature', u'properties': {u'rms': None, u'code': u'p0009rst', u'cdi': None, u'sources': u',us,', u'nst': None, u'tz': None, u'title': u'M 2.6 - England, United Kingdom', u'magType': u'ml', u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp0009rst&format=geojson', u'sig': 104, u'net': u'us', u'type': u'earthquake', u'status': u'reviewed', u'updated': 1415322596133, u'felt': None, u'gap': None, u'dmin': None, u'mag': 2.6, u'alert': None, u'types': u',impact-text,origin,phase-data,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp0009rst', u'ids': u',usp0009rst,', u'tsunami': 0, u'place': u'England, United Kingdom', u'time': 956553055700, u'mmi': None}, u'id': u'usp0009rst'}, {u'geometry': {u'type': u'Point', u'coordinates': [-1.61, 52.28, 13.1]}, u'type': u'Feature', u'properties': {u'rms': None, u'code': u'p000a0pm', u'cdi': None, u'sources': u',us,', u'nst': 55, u'tz': None, u'title': u'M 4.0 - England, United Kingdom', u'magType': u'ml', u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a0pm&format=geojson', u'sig': 246, u'net': u'us', u'type': u'earthquake', u'status': u'reviewed', u'updated': 1415322666913, u'felt': None, u'gap': None, u'dmin': None, u'mag': 4, u'alert': None, u'types': u',impact-text,origin,phase-data,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a0pm', u'ids': u',usp000a0pm,', u'tsunami': 0, u'place': u'England, United Kingdom', u'time': 969683025790, u'mmi': None}, u'id': u'usp000a0pm'}, {u'geometry': {u'type': u'Point', u'coordinates': [1.564, 53.236, 10]}, u'type': u'Feature', u'properties': {u'rms': 1.12, u'code': u'p000a6hd', u'cdi': None, u'sources': u',us,', u'nst': 27, u'tz': None, u'title': u'M 4.0 - North Sea', u'magType': u'ml', u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000a6hd&format=geojson', u'sig': 246, u'net': u'us', u'type': u'earthquake', u'status': u'reviewed', u'updated': 1415322705662, u'felt': None, u'gap': None, u'dmin': None, u'mag': 4, u'alert': None, u'types': u',origin,phase-data,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000a6hd', u'ids': u',usp000a6hd,', u'tsunami': 0, u'place': u'North Sea', u'time': 977442788510, u'mmi': None}, u'id': u'usp000a6hd'}, {u'geometry': {u'type': u'Point', u'coordinates': [0.872, 58.097, 10]}, u'type': u'Feature', u'properties': {u'rms': 1.44, u'code': u'p000abdr', u'cdi': None, u'sources': u',us,', u'nst': 36, u'tz': None, u'title': u'M 3.3 - North Sea', u'magType': u'mb', u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000abdr&format=geojson', u'sig': 168, u'net': u'us', u'type': u'earthquake', u'status': u'reviewed', u'updated': 1415322741153, u'felt': None, u'gap': None, u'dmin': None, u'mag': 3.3, u'alert': None, u'types': u',origin,phase-data,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000abdr', u'ids': u',usp000abdr,', u'tsunami': 0, u'place': u'North Sea', u'time': 984608438660, u'mmi': None}, u'id': u'usp000abdr'}, {u'geometry': {u'type': u'Point', u'coordinates': [-1.845, 51.432, 10]}, u'type': u'Feature', u'properties': {u'rms': 0.57, u'code': u'p000abnc', u'cdi': None, u'sources': u',us,', u'nst': 19, u'tz': None, u'title': u'M 2.9 - England, United Kingdom', u'magType': u'ml', u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000abnc&format=geojson', u'sig': 129, u'net': u'us', u'type': u'earthquake', u'status': u'reviewed', u'updated': 1415322742102, u'felt': None, u'gap': None, u'dmin': None, u'mag': 2.9, u'alert': None, u'types': u',origin,phase-data,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000abnc', u'ids': u',usp000abnc,', u'tsunami': 0, u'place': u'England, United Kingdom', u'time': 984879824720, u'mmi': None}, u'id': u'usp000abnc'}, {u'geometry': {u'type': u'Point', u'coordinates': [-3.639, 55.102, 12.3]}, u'type' ...
